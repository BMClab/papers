# %% [markdown]
# # Effects of age and speed on ankle–foot power during walking
#
# > [Laboratory of Biomechanics and Motor Control](http://demotu.org/)
# > Federal University of ABC, Brazil

# %% [markdown]
# <h1>Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Setup" data-toc-modified-id="Setup-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Setup</a></span><ul class="toc-item"><li><span><a href="#Helper-functions" data-toc-modified-id="Helper-functions-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Helper functions</a></span></li></ul></li><li><span><a href="#Data" data-toc-modified-id="Data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data</a></span><ul class="toc-item"><li><span><a href="#Independent-variables:-age-and-speed" data-toc-modified-id="Independent-variables:-age-and-speed-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Independent variables: age and speed</a></span></li><li><span><a href="#Dependent-variables:-ankle-foot-system-power" data-toc-modified-id="Dependent-variables:-ankle-foot-system-power-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Dependent variables: ankle-foot system power</a></span></li></ul></li><li><span><a href="#Regression-analyses" data-toc-modified-id="Regression-analyses-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Regression analyses</a></span><ul class="toc-item"><li><span><a href="#Age-(categorical)-and-Speed-(continuous)" data-toc-modified-id="Age-(categorical)-and-Speed-(continuous)-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Age (categorical) and Speed (continuous)</a></span><ul class="toc-item"><li><span><a href="#Remove-data-from-subject-outside-age-groups-(50-year-old-subject)" data-toc-modified-id="Remove-data-from-subject-outside-age-groups-(50-year-old-subject)-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Remove data from subject outside age groups (50 year old subject)</a></span></li><li><span><a href="#Descriptive-statistics" data-toc-modified-id="Descriptive-statistics-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Descriptive statistics</a></span></li><li><span><a href="#Simple-tests-for-differences-between-age-groups" data-toc-modified-id="Simple-tests-for-differences-between-age-groups-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Simple tests for differences between age groups</a></span></li><li><span><a href="#Data-standardization/normalization" data-toc-modified-id="Data-standardization/normalization-3.1.4"><span class="toc-item-num">3.1.4&nbsp;&nbsp;</span>Data standardization/normalization</a></span></li><li><span><a href="#Replace-letters-by-numeric-values-because-it's-easier-to-identify-the-effect" data-toc-modified-id="Replace-letters-by-numeric-values-because-it's-easier-to-identify-the-effect-3.1.5"><span class="toc-item-num">3.1.5&nbsp;&nbsp;</span>Replace letters by numeric values because it's easier to identify the effect</a></span></li><li><span><a href="#Run-models-for-all-predictors-and-responses" data-toc-modified-id="Run-models-for-all-predictors-and-responses-3.1.6"><span class="toc-item-num">3.1.6&nbsp;&nbsp;</span>Run models for all predictors and responses</a></span></li><li><span><a href="#Table-with-model-results" data-toc-modified-id="Table-with-model-results-3.1.7"><span class="toc-item-num">3.1.7&nbsp;&nbsp;</span>Table with model results</a></span></li><li><span><a href="#Effect-size-of-regression-coefficients" data-toc-modified-id="Effect-size-of-regression-coefficients-3.1.8"><span class="toc-item-num">3.1.8&nbsp;&nbsp;</span>Effect size of regression coefficients</a></span></li><li><span><a href="#Likelihood-Ratio-Test" data-toc-modified-id="Likelihood-Ratio-Test-3.1.9"><span class="toc-item-num">3.1.9&nbsp;&nbsp;</span>Likelihood-Ratio Test</a></span></li><li><span><a href="#Plots-with-linear-regressions-per-age-group" data-toc-modified-id="Plots-with-linear-regressions-per-age-group-3.1.10"><span class="toc-item-num">3.1.10&nbsp;&nbsp;</span>Plots with linear regressions per age group</a></span></li><li><span><a href="#Partial-regression-plots-of-the-model-for-the-feature-'W-foot'" data-toc-modified-id="Partial-regression-plots-of-the-model-for-the-feature-'W-foot'-3.1.11"><span class="toc-item-num">3.1.11&nbsp;&nbsp;</span>Partial regression plots of the model for the feature 'W-foot'</a></span></li><li><span><a href="#Plot-of-the-residuals" data-toc-modified-id="Plot-of-the-residuals-3.1.12"><span class="toc-item-num">3.1.12&nbsp;&nbsp;</span>Plot of the residuals</a></span></li><li><span><a href="#Verification-that-non-normality-of-few-residuals-are-due-to-outliers" data-toc-modified-id="Verification-that-non-normality-of-few-residuals-are-due-to-outliers-3.1.13"><span class="toc-item-num">3.1.13&nbsp;&nbsp;</span>Verification that non-normality of few residuals are due to outliers</a></span></li><li><span><a href="#The-model-results-are-not-affected-by-the-order-of-the-predictors" data-toc-modified-id="The-model-results-are-not-affected-by-the-order-of-the-predictors-3.1.14"><span class="toc-item-num">3.1.14&nbsp;&nbsp;</span>The model results are not affected by the order of the predictors</a></span></li></ul></li><li><span><a href="#Age-(continuous)-and-Speed-(continuous)" data-toc-modified-id="Age-(continuous)-and-Speed-(continuous)-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Age (continuous) and Speed (continuous)</a></span><ul class="toc-item"><li><span><a href="#Data-standardization/normalization" data-toc-modified-id="Data-standardization/normalization-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Data standardization/normalization</a></span></li><li><span><a href="#Replace-letters-by-numeric-values-because-it's-easier-to-identify-the-effect" data-toc-modified-id="Replace-letters-by-numeric-values-because-it's-easier-to-identify-the-effect-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Replace letters by numeric values because it's easier to identify the effect</a></span></li><li><span><a href="#Run-models-for-all-predictors-and-responses" data-toc-modified-id="Run-models-for-all-predictors-and-responses-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Run models for all predictors and responses</a></span></li><li><span><a href="#Table-with-model-results" data-toc-modified-id="Table-with-model-results-3.2.4"><span class="toc-item-num">3.2.4&nbsp;&nbsp;</span>Table with model results</a></span></li><li><span><a href="#Likelihood-Ratio-Test" data-toc-modified-id="Likelihood-Ratio-Test-3.2.5"><span class="toc-item-num">3.2.5&nbsp;&nbsp;</span>Likelihood-Ratio Test</a></span></li></ul></li><li><span><a href="#Age-(categorical)-and-Speed-(continuous):-slower-half-of-old-vs.-faster-half-of-young-subjects" data-toc-modified-id="Age-(categorical)-and-Speed-(continuous):-slower-half-of-old-vs.-faster-half-of-young-subjects-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Age (categorical) and Speed (continuous): slower half of old vs. faster half of young subjects</a></span><ul class="toc-item"><li><span><a href="#Descriptive-statistics" data-toc-modified-id="Descriptive-statistics-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Descriptive statistics</a></span></li><li><span><a href="#Simple-tests-for-differences-between-age-groups" data-toc-modified-id="Simple-tests-for-differences-between-age-groups-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Simple tests for differences between age groups</a></span></li><li><span><a href="#Data-standardization/normalization" data-toc-modified-id="Data-standardization/normalization-3.3.3"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>Data standardization/normalization</a></span></li><li><span><a href="#Replace-letters-by-numeric-values-because-it's-easier-to-identify-the-effect" data-toc-modified-id="Replace-letters-by-numeric-values-because-it's-easier-to-identify-the-effect-3.3.4"><span class="toc-item-num">3.3.4&nbsp;&nbsp;</span>Replace letters by numeric values because it's easier to identify the effect</a></span></li><li><span><a href="#Run-models-for-all-predictors-and-responses" data-toc-modified-id="Run-models-for-all-predictors-and-responses-3.3.5"><span class="toc-item-num">3.3.5&nbsp;&nbsp;</span>Run models for all predictors and responses</a></span></li><li><span><a href="#Table-with-model-results" data-toc-modified-id="Table-with-model-results-3.3.6"><span class="toc-item-num">3.3.6&nbsp;&nbsp;</span>Table with model results</a></span></li><li><span><a href="#The-model-results-are-not-affected-by-the-order-of-the-predictors" data-toc-modified-id="The-model-results-are-not-affected-by-the-order-of-the-predictors-3.3.7"><span class="toc-item-num">3.3.7&nbsp;&nbsp;</span>The model results are not affected by the order of the predictors</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# ## Setup

# %%
import sys, os
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import sys, os
import pingouin as pg
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.stats.api as sms
from scipy import stats
from IPython.display import HTML
import pyversions  # https://pypi.org/project/pyversions/

sns.set_style('whitegrid')
sns.set_context('notebook', font_scale=1.1)
pd.set_option('precision', 3)
import warnings
warnings.filterwarnings("ignore")

pyversions.versions();
# Out:
# Linux 5.4.0-39-generic 64-bit #43-Ubuntu SMP Fri Jun 19 10:28:31 UTC 2020
# CPython 3.7.6 packaged by conda-forge (default, Jun  1 2020, 18:57:50) [GCC 7.5.0]
# Jun 27 2020, 22:37:47
#
# Module            Version
# ipython            7.16.1
# matplotlib          3.2.2
# notebook            6.0.3
# numpy              1.18.5
# pandas              1.0.5
# pingouin            0.3.5
# pyversions          0.0.3
# scipy               1.5.0
# seaborn            0.10.1
# statsmodels        0.11.1

# %% [markdown]
# ### Helper functions

# %%
def pnorm(df):
    """Get the p-val of the normality (Shapiro-Wilk) test using the pingouin.
    """
    return pg.normality(df)['pval']


def sig_red(col, alpha=0.05):
    """Returns string 'color: red' for `col` < `alpha`, black otherwise.
    """
    col = np.array([(float(x[1:]) if isinstance(x, str) else float(x))
                    if len(str(x)) else np.nan for x in col])
    
    is_sig = col < alpha
    return ['color: red' if x else 'color: black' for x in is_sig]


def describe(df, by=None, var=['mean', 'std', pnorm]):
    """Descriptive statistics for dataframe columns.
    """
    x = df.groupby(by).agg(var).stack().transpose()
    x.rename(columns={'pnorm': 'p'}, inplace=True)
    display(x.style.apply(sig_red, axis=0,
                          subset=[col for col in x.columns if col[-1] == 'p'])) 
    return x


def ttest(df, var, factor, levels=None, alpha=0.05):
    """t-test statistcs for dataframe columns using the pingouin library.
    """
    stats = pd.DataFrame()
    if levels is None:
        levels = df[factor].unique()
    if len(levels) != 2:
        raise Exception('Incorrect number of levels: {}'.format(len(levels)))
    for v in var:
        x = df[df[factor] == levels[0]][v]
        y = df[df[factor] == levels[1]][v]
        stat = pg.ttest(x, y)
        stat.index = [v]
        stats = pd.concat([stats, stat], axis=0)
    stats.drop(columns=['tail', 'BF10', 'power'], inplace=True)
    stats.index.name = '{}-{}'.format(*levels)
    display(stats.style.format({'p-val': '{:.3f}'}).apply(sig_red, subset='p-val', axis=1))
    return stats


def regression(fit_ml, fit_re, names):
    """Get results from linear regression as list.

    results = ['Response', 'Coef', 'CI', 'p', 'Coef', 'CI', 'p', Coef', 'CI', 'p',
               'llf', 'AIC', 'R2']
    """
    # print(fit_re.model.exog_names)
    if names is None:
        names = fit_re.model.exog_names[1:]
    results = [np.nan]*(1 + len(names)*3 + 3)
    # response
    results[ 0] = fit_re.model.endog_names
    # log-likelihood function
    results[-3] = '{:.1f}'.format(fit_ml.llf)
    # Akaike information criterion
    results[-2] = '{:.1f}'.format(fit_ml.aic)
    # marginal R2, proportion of variance explained by the fixed factor(s) alone
    results[-1] = '{:.2f}'.format(np.corrcoef(fit_re.model.endog, fit_re.predict())[0, 1]**2)
    # conditional R2, proportion of variance explained by both the fixed and random factors
    #results[-1] = np.round(np.corrcoef(fit_re.model.endog , fit_re.fittedvalues)[0, 1]**2, 2)
    for name in fit_re.model.exog_names[1:]:
        idx = names.index(name)
        # fitted fixed-effects coefficients
        results[3*idx+1] = '{:.2f}'.format(fit_re.params[name])
        # confidence interval for the fitted parameters
        ci = fit_re.conf_int().loc[name].values
        results[3*idx+2] = '[{:.2f}, {:.2f}]'.format(ci[0], ci[1])
        # two-tailed p values for the t-stats of the params
        if fit_re.pvalues[name] < 0.0001:
            results[3*idx+3] = '< 0.0001'
        else:
            results[3*idx+3] = '{:.4f}'.format(fit_re.pvalues[name])

    return results


def runmodels(data, predictors, responses, groups, names):
    """Run mixed linear regression models.
    """
    fit_ml = []
    fit_re = []
    models = []
    i = 0
    print('Running regression models...')
    for response in responses:
        for predictor in predictors:
            eq = '{} ~ {}'.format(response, predictor)
            md = smf.mixedlm(formula=eq, data=data, groups=groups)
            # use ML method to estimate AIC and llf
            fit_ml.append(md.fit(reml=False))
            # use REML method to get unbiased estimations of the coefficients
            fit_re.append(md.fit(reml=True))
            models.append(regression(fit_ml[-1], fit_re[-1], names=names))
            text = 'converged' if fit_re[-1].converged else 'didn\'t converge'
            print('Model {:2}: {} {}.'.format(i, eq, text))
            #display(fit_re[-1].summary())
            i += 1
    print('...done.')
    
    return models, fit_ml, fit_re


def display_table(models):
    """Display rich table with stats from regression models.
    """
    h0, h1, h2 = ['Feature'], ['Feature'], ['Feature']
    h0.extend(['Predictor']*3*len(names))
    for name in names:
        h1.extend(name*3)
    h2.extend(['Coef', 'CI', 'p-value']*len(names))
    h0.extend(['LLF', 'AIC', 'R2'])
    h1.extend(['LLF', 'AIC', 'R2'])
    h2.extend(['LLF', 'AIC', 'R2'])
    table = pd.DataFrame(data=models)
    table.columns=[h0, h1, h2]
    table.replace({np.nan: '', 'Wpankle': 'W+ankle', 'Wnankle': 'W-ankle',
                  'Wpfoot': 'W+foot', 'Wnfoot': 'W-foot',
                  'Wpsum': 'W+sum', 'Wnsum': 'W-sum'}, inplace=True)
    #table.to_csv(os.path.join(path2, 'table_regression.csv'), sep='\t', index=False)
    table = table.style \
            .apply(sig_red, subset=[c for c in table.columns if c[-1] == 'p-value']) \
            .set_table_styles([dict(selector='th', props=[('text-align', 'center')])])
    
    return table


def plot_scatter(df, fit_re, predictors, responses, labels):
    """Plot data and regression model for dependent variables.
    """
    df2 = df.copy(deep=True).reset_index()
    respn = ['v'+str(i) for i in range(len(responses))]
    df2 = df2.rename(columns=dict(zip(responses, respn)), inplace=False)
    df2 = pd.wide_to_long(df2, stubnames=['v'],
                          i='index', j='Variable', suffix='\d+').reset_index()

    g = sns.lmplot(x='Speed', y='v', hue='AgeGroup', col='Variable', data=df2, markers=['^', 'v'],
                   ci=None, line_kws={'linestyle': '--'}, scatter_kws={'alpha':.5}, 
                   fit_reg=False, legend_out=False,
                   truncate=True, sharex=False, sharey=False, col_wrap=3, height=2.8, aspect=1.3)
    g.set_axis_labels('Speed (m/s)', '')
    for i, ax in enumerate(g.axes):
        x = fit_re[len(predictors)*i].model.exog[:, -1]*df.iloc[:, 9].std() + df.iloc[:, 9].mean()
        y = fit_re[len(predictors)*i].predict()*df.iloc[:, i+11].std() + df.iloc[:, i+11].mean()
        sns.lineplot(x=x, y=y, ci=None, color='g', alpha=1, lw=3, label='All', ax=ax)
        if i == 7:
            c = fit_re[len(predictors)*i + 2].params  # Wnfoot
            idx = fit_re[len(predictors)*i + 2].model.exog[:, 1] == 0  # young adults
            xy = fit_re[len(predictors)*i + 2].model.exog[idx, -1]  # speed
            yy = c['Intercept'] + c['C(AgeGroup)[T.1]']*0 + c['Speed']*xy
            xy = xy*df.iloc[:, 9].std() + df.iloc[:, 9].mean()
            yy = yy*df.iloc[:, i+11].std() + df.iloc[:, i+11].mean()
            ax.plot(xy, yy, color='b', alpha=1, lw=2, label='Y', linestyle='-')     
            idx = fit_re[len(predictors)*i + 2].model.exog[:, 1] == 1  # older adults
            xo = fit_re[len(predictors)*i + 2].model.exog[idx, -1]  # speed
            yo = c['Intercept'] + c['C(AgeGroup)[T.1]']*1 + c['Speed']*xo
            xo = xo*df.iloc[:, 9].std() + df.iloc[:, 9].mean()
            yo = yo*df.iloc[:, i+11].std() + df.iloc[:, i+11].mean()
            ax.plot(xo, yo, color='r', alpha=1, lw=2, label='O', linestyle='-')
            hands, labs = ax.get_legend_handles_labels()
            ax.legend(hands[:3], labs[:3], frameon=False, loc='best', title='AgeGroup', fontsize=10)

        ax.margins(x=.05, y=.2)
        ax.set_title(labels[i])
        ax.xaxis.set_major_locator(plt.MultipleLocator(.25))
        ax.xaxis.set_minor_locator(plt.MultipleLocator(.25))
        ax.grid(b=None)  # which='both', alpha=.5
        if i < 6:
            ax.set_xticklabels([])
        if i == 0:
            ax.legend(frameon=False, loc='best', title='AgeGroup', fontsize=10)
        elif i == 7:
            pass
        else:
            ax.get_legend().remove()
    g.fig.subplots_adjust(wspace=.15, hspace=.2)
    plt.show()
    #g.savefig(os.path.join(path2, 'regression.png'))
    
    
def plot_residuals(df, fit_re, predictors):
    """Plot residuals from fit_re model.
    """
    var = ['Pankle', 'Pfoot', 'Psum', 'Wpankle', 'Wpfoot', 'Wpsum',
           'Wnankle', 'Wnfoot', 'Wnsum']
    labels = ['Pankle (W/kg)', 'Pfoot (W/kg)', 'Psum (W/kg)', 'W+ankle (J/kg)', 'W+foot (J/kg)',
              'W+sum (J/kg)', 'W-ankle (J/kg)','W-foot (J/kg)','W-sum (J/kg)']
    fig, axs = plt.subplots(3, 3, sharex=True, figsize=(13, 9))
    axs = axs.flatten()
    for i, ax in enumerate(axs):
        speed = fit_re[len(predictors)*i].model.exog[:, 1]*df.iloc[:, 9].std() + df.iloc[:, 9].mean()
        resid = (fit_re[len(predictors)*i].predict()-fit_re[len(predictors)*i].model.endog)
        sns.scatterplot(x=speed, y=resid, ax=ax)

        # Jarque–Bera normality of residuals test
        test = sms.jarque_bera(resid)[1]
        # Shapiro-Wilk test
        #test = pnorm(resid).values[0]

        if i > 5:
            ax.set_xlabel('Speed (m/s)')
        ax.set_title(labels[i] + ' p-norm={:.3f}'.format(test))
        ax.xaxis.set_major_locator(plt.MultipleLocator(.25))
        ax.xaxis.set_minor_locator(plt.MultipleLocator(.25))
        ax.grid(None)  # which='both', alpha=.5
        ax.spines['right'].set_visible(False)
        ax.spines['top'].set_visible(False)
        ax.axhline(0, c='k', alpha=.5)
        ax.margins(y=.25)  

    fig.subplots_adjust(wspace=.15, hspace=.2)
    plt.show()
    fig.savefig(os.path.join(path2, 'residual.png'))

# %% [markdown]
# ## Data

# %%
name = 'UD_stats_all_speeds_2.csv'
path2 = r'./../data'
fname = os.path.join(path2, name)
data0 = pd.read_csv(fname, sep=',', header=0, index_col=0)
display(data0)
# Out:
#      Subject AgeGroup SpeedGroup Gender  Age  Height   Mass     BMI  LegLen  \
# 0          1        Y          S      M   25   1.725  74.30  24.970   0.890
# 41         1        Y          C      M   25   1.725  74.30  24.970   0.890
# 82         1        Y          F      M   25   1.725  74.30  24.970   0.890
# 1          2        Y          S      F   22   1.668  52.90  19.014   0.865
# 42         2        Y          C      F   22   1.668  52.90  19.014   0.865
# ..       ...      ...        ...    ...  ...     ...    ...     ...     ...
# 80        41        O          C      F   55   1.495  74.05  33.132   0.750
# 121       41        O          F      F   55   1.495  74.05  33.132   0.750
# 40        42        O          S      F   63   1.612  59.85  23.032   0.820
# 81        42        O          C      F   63   1.612  59.85  23.032   0.820
# 122       42        O          F      F   63   1.612  59.85  23.032   0.820
#
# ...

# %% [markdown]
# ### Independent variables: age and speed
#
# The data set contains data from 41 individuals, each walking at three self-selected speeds in relation to their corresponding comfortable speed: slow, comfortable, fast (see the pair plots in figure below).
#
# It can be seen that the age of the subjects is grouped into two categories of younger and older subjects. If we remove a 50 year old subject, the remaining 40 subjects can be organized into two age groups: Young (21 - 37 years old) and Old (55 - 84 years old).
#
# Although each subject walked at only three speeds, it can be seen that considering all subjects, the walking speeds spread continuously over the interval (0.62 - 1.88 m/s).
#
# Because of that, our main analysis on the effects of age and speed will treat age as a categorical dichotomous variable (Y, O) and speed as a continuous variable.
# And to test the robustness of the results, we will also perform analysis considering age as a continuous variable.

# %%
labels2 = ['Age (years)', 'Speed (m/s)']
g = sns.pairplot(data0, hue='SpeedGroup', vars=['Age', 'Speed'], diag_kind='hist',
                 markers=['v', 'o', '^'], plot_kws={'s':80},
                 diag_kws={'alpha':.5, 'bins':12}, height=2.5, aspect=1.5)
axs = g.axes.flatten()
for i in range(len(labels2)):
    axs[int(i*len(labels2))].set_ylabel(labels2[i])
    axs[int(i*len(labels2))].yaxis.set_label_coords(-0.25, .5)
    axs[int(i+(len(labels2)-1)*len(labels2))].set_xlabel(labels2[i])
g.fig.align_ylabels(g.axes[:, 0])
g.fig.subplots_adjust(left=0.2, wspace=0.1)
plt.show()
display(HTML("Figure. Pairs plots and histograms of subjects' age and walking speed (N=41)."))
# Out:
# Figure. Pairs plots and histograms of subjects' age and walking speed (N=41).

# %% [markdown]
# ### Dependent variables: ankle-foot system power

# %%
features = ['Pankle', 'Pfoot', 'Psum',
             'Wpankle', 'Wpfoot', 'Wpsum',
             'Wnankle', 'Wnfoot', 'Wnsum']
labels   = ['Pankle (W/kg)', 'Pfoot (W/kg)', 'Psum (W/kg)',
            'W+ankle (J/kg)', 'W+foot (J/kg)', 'W+sum (J/kg)',
            'W-ankle (J/kg)', 'W-foot (J/kg)', 'W-sum (J/kg)']

# %% [markdown]
# ## Regression analyses

# %% [markdown]
# ### Age (categorical) and Speed (continuous)

# %% [markdown]
# #### Remove data from subject outside age groups (50 year old subject)

# %%
data1 = data0.drop(index=data0[(data0.Age > 40) & (data0.Age < 55)].index, inplace=False)

# %%
labels2 = ['Age (years)', 'Speed (m/s)']
g = sns.pairplot(data1, hue='SpeedGroup', vars=['Age', 'Speed'], diag_kind='hist',
                 markers=['v', 'o', '^'], plot_kws={'s':80},
                 diag_kws={'alpha':.5, 'bins':12}, height=2.5, aspect=1.5)
axs = g.axes.flatten()
for i in range(len(labels2)):
    axs[int(i*len(labels2))].set_ylabel(labels2[i])
    axs[int(i*len(labels2))].yaxis.set_label_coords(-0.25, .5)
    axs[int(i+(len(labels2)-1)*len(labels2))].set_xlabel(labels2[i])
g.fig.align_ylabels(g.axes[:, 0])
g.fig.subplots_adjust(left=0.2, wspace=0.1)
plt.show()
display(HTML("Figure. Pairs plots and histograms of subjects' age and walking speed (N=40)."))
g.fig.savefig(os.path.join(path2, 'agespeed1.png'))
# Out:
# Figure. Pairs plots and histograms of subjects' age and walking speed (N=40).

# %% [markdown]
# #### Descriptive statistics

# %%
display(HTML('<b>Number of subjects per age group and speed condition:</b>'))
display(data1[['Subject', 'AgeGroup',
               'SpeedGroup']].groupby(['AgeGroup','SpeedGroup']).agg('count').T)
var = ['AgeGroup', 'Age', 'Height', 'Mass', 'BMI', 'LegLen']
info = data1.drop_duplicates(subset='Subject')[var]
describe(info, 'AgeGroup');
stats0 = ttest(info, var[1:], 'AgeGroup', levels=['O', 'Y'])
# Out:
# <b>Number of subjects per age group and speed condition:</b>
# AgeGroup     O           Y
# SpeedGroup   C   F   S   C   F   S
# Subject     16  16  16  24  24  24
# <style  type="text/css" >
#     #T_f9f2c1e0_b8df_11ea_b729_d09466a86f4arow0_col2 {
#             color:  red;
#         }    #T_f9f2c1e0_b8df_11ea_b729_d09466a86f4arow0_col5 {
#             color:  black;
#         }    #T_f9f2c1e0_b8df_11ea_b729_d09466a86f4arow1_col2 {
#             color:  black;
#         }    #T_f9f2c1e0_b8df_11ea_b729_d09466a86f4arow1_col5 {
#             color:  black;
#         }    #T_f9f2c1e0_b8df_11ea_b729_d09466a86f4arow2_col2 {
#             color:  red;
#         }    #T_f9f2c1e0_b8df_11ea_b729_d09466a86f4arow2_col5 {
#             color:  black;
#         }    #T_f9f2c1e0_b8df_11ea_b729_d09466a86f4arow3_col2 {
#             color:  black;
#         }    #T_f9f2c1e0_b8df_11ea_b729_d09466a86f4arow3_col5 {
#             color:  black;
# ...

# %%
display(HTML('<b>Mean and STD values per age group and speed condition:</b>'))
df = data1[['AgeGroup', 'SpeedGroup', 'Speed'] + features]
df = data1[['AgeGroup', 'SpeedGroup', 'Speed', 'StanceTime'] + features]
describe(df, ['AgeGroup', 'SpeedGroup'], var=['mean', 'std']);
display(HTML('<b>Mean and STD values per age group and overall:</b>'))
agegroup = df.groupby('AgeGroup').agg(['mean', 'std']).stack().transpose()
overall = df.agg(['mean', 'std']).transpose()
overall.columns = [['All', 'All'], ['mean', 'std']]
overall.columns.set_names(names=['AgeGroup', None], level=[0, 1], inplace=True)
table_msd = pd.concat([agegroup, overall], axis=1)
table_msd.to_csv(os.path.join(path2, 'table_msd.csv'), float_format='%.3f', sep='\t')
display(table_msd)
# Out:
# <b>Mean and STD values per age group and speed condition:</b>
# <style  type="text/css" >
# ...

# %% [markdown]
# #### Simple tests for differences between age groups

# %%
var = ['SpeedGroup', 'AgeGroup', 'Speed', 'StanceTime'] + features
print('Slow speed')
stats0 = ttest(data1[data1['SpeedGroup']=='S'][var], var[2:], 'AgeGroup', levels=['O', 'Y'])
print('Comfortable speed')
stats0 = ttest(data1[data1['SpeedGroup']=='C'][var], var[2:], 'AgeGroup', levels=['O', 'Y'])
print('Fast speed')
stats0 = ttest(data1[data1['SpeedGroup']=='F'][var], var[2:], 'AgeGroup', levels=['O', 'Y'])
# Out:
# Slow speed
# <style  type="text/css" >
#     #T_fa1133b4_b8df_11ea_b729_d09466a86f4arow0_col2 {
#             color:  black;
#         }    #T_fa1133b4_b8df_11ea_b729_d09466a86f4arow1_col2 {
#             color:  black;
#         }    #T_fa1133b4_b8df_11ea_b729_d09466a86f4arow2_col2 {
#             color:  black;
#         }    #T_fa1133b4_b8df_11ea_b729_d09466a86f4arow3_col2 {
#             color:  black;
#         }    #T_fa1133b4_b8df_11ea_b729_d09466a86f4arow4_col2 {
#             color:  black;
#         }    #T_fa1133b4_b8df_11ea_b729_d09466a86f4arow5_col2 {
#             color:  black;
#         }    #T_fa1133b4_b8df_11ea_b729_d09466a86f4arow6_col2 {
#             color:  black;
#         }    #T_fa1133b4_b8df_11ea_b729_d09466a86f4arow7_col2 {
#             color:  black;
#         }    #T_fa1133b4_b8df_11ea_b729_d09466a86f4arow8_col2 {
#             color:  black;
#         }    #T_fa1133b4_b8df_11ea_b729_d09466a86f4arow9_col2 {
#             color:  black;
# ...

# %%
variables = ['Speed'] + features
labels2 = ['Speed (m/s)'] + labels
fig, axs = plt.subplots(2, 5, figsize=(14, 8), sharex=True,
                        gridspec_kw={'hspace': .1, 'wspace': .3})
axs = axs.flatten()
for i, ax, v, label in zip(range(len(axs)), axs, variables, labels2):
    sns.violinplot(x='AgeGroup', y=v, data=data1, inner='point',
                   dodge=True, saturation=0.5, ax=ax)
    ax.set_title(label)
    if i < 5:
        ax.set_xlabel('')
        ax.set_xticklabels([])
    ax.set_ylabel('')
plt.show()

# %%
variables = ['Speed'] + features
labels2 = ['Speed (m/s)'] + labels
fig, axs = plt.subplots(2, 5, figsize=(14, 8), sharex=True,
                        gridspec_kw={'hspace': .1, 'wspace': .3})
axs = axs.flatten()
for i, ax, v, label in zip(range(len(axs)), axs, variables, labels2):
    sns.stripplot(x='SpeedGroup', y=v, data=data1, ax=ax, hue='AgeGroup', jitter=True,
                  edgecolor='gray', linewidth=1, dodge=True)
    sns.boxplot(x='SpeedGroup', y=v, data=data1, ax=ax, hue='AgeGroup')
    handles, labels3 = ax.get_legend_handles_labels()
    if i == 5:
        ax.legend(handles[:2], labels3[:2], frameon=False, loc='best', title='AgeGroup')
    else:
        ax.get_legend().remove()
    ax.set_title(label)
    if i < 5:
        ax.set_xlabel('')
        ax.set_xticklabels([])
    ax.set_ylabel('')
plt.show()

# %% [markdown]
# #### Data standardization/normalization

# %%
df1 = data1.copy(deep=True)
var = ['Speed'] + features
# Standardization (mean 0, variance 1)
df1[var] = df1[var].apply(lambda x: (x-x.mean())/x.std(), axis=0)

# %% [markdown]
# #### Replace letters by numeric values because it's easier to identify the effect
#
# E.g.: {'Y': 0, 'O': 1} implies that if there is an effect of Age and its coefficient (slope) is positive, it means that the response increases for older subjects and decreases for young subjects. Internally the letters were replaced by numbers anyway but we didn't know the order.

# %%
df1.loc[:, 'AgeGroup'].replace({'Y': 0, 'O': 1}, inplace=True)

# %% [markdown]
# #### Run models for all predictors and responses

# %%
predictors = ['Speed',
              'C(AgeGroup)',
              'Speed + C(AgeGroup)', 
              'Speed * C(AgeGroup)']
groups     = df1['Subject']

names      = ['Speed', 'C(AgeGroup)[T.1]', 'Speed:C(AgeGroup)[T.1]']
models1, fit_ml1, fit_re1  = runmodels(df1, predictors, features, groups, names)
# Out:
# Running regression models...
# Model  0: Pankle ~ Speed converged.
# Model  1: Pankle ~ C(AgeGroup) converged.
# Model  2: Pankle ~ Speed + C(AgeGroup) converged.
# Model  3: Pankle ~ Speed * C(AgeGroup) converged.
# Model  4: Pfoot ~ Speed converged.
# Model  5: Pfoot ~ C(AgeGroup) converged.
# Model  6: Pfoot ~ Speed + C(AgeGroup) converged.
# Model  7: Pfoot ~ Speed * C(AgeGroup) converged.
# Model  8: Psum ~ Speed converged.
# Model  9: Psum ~ C(AgeGroup) converged.
# Model 10: Psum ~ Speed + C(AgeGroup) converged.
# Model 11: Psum ~ Speed * C(AgeGroup) converged.
# Model 12: Wpankle ~ Speed converged.
# Model 13: Wpankle ~ C(AgeGroup) converged.
# Model 14: Wpankle ~ Speed + C(AgeGroup) converged.
# Model 15: Wpankle ~ Speed * C(AgeGroup) converged.
# Model 16: Wpfoot ~ Speed converged.
# Model 17: Wpfoot ~ C(AgeGroup) converged.
# Model 18: Wpfoot ~ Speed + C(AgeGroup) converged.
# Model 19: Wpfoot ~ Speed * C(AgeGroup) converged.
# Model 20: Wpsum ~ Speed converged.
# ...

# %%
fit_re1[30].summary()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#            Mixed Linear Model Regression Results
# ...
# Model:              MixedLM   Dependent Variable:   Wnfoot
# No. Observations:   120       Method:               REML
# No. Groups:         40        Scale:                0.1844
# Min. group size:    3         Log-Likelihood:       -94.8107
# Max. group size:    3         Converged:            Yes
# Mean group size:    3.0
# ------------------------------------------------------------
#                  Coef.  Std.Err.    z    P>|z| [0.025 0.975]
# ------------------------------------------------------------
# Intercept         0.174    0.089   1.962 0.050  0.000  0.348
# C(AgeGroup)[T.1] -0.435    0.140  -3.102 0.002 -0.710 -0.160
# Speed            -0.819    0.043 -19.242 0.000 -0.902 -0.735
# Group Var         0.127    0.123
# ...
#
# """

# %%
fit_re1[31].summary()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#               Mixed Linear Model Regression Results
# ...
# Model:                MixedLM     Dependent Variable:     Wnfoot
# No. Observations:     120         Method:                 REML
# No. Groups:           40          Scale:                  0.1691
# Min. group size:      3           Log-Likelihood:         -91.7148
# Max. group size:      3           Converged:              Yes
# Mean group size:      3.0
# ------------------------------------------------------------------
#                        Coef.  Std.Err.    z    P>|z| [0.025 0.975]
# ------------------------------------------------------------------
# Intercept               0.171    0.087   1.961 0.050  0.000  0.341
# C(AgeGroup)[T.1]       -0.440    0.138  -3.201 0.001 -0.710 -0.171
# Speed                  -0.720    0.052 -13.919 0.000 -0.822 -0.619
# Speed:C(AgeGroup)[T.1] -0.262    0.084  -3.102 0.002 -0.427 -0.096
# Group Var               0.125    0.123
# ...
#
# """

# %% [markdown]
# #### Table with model results

# %%
names = [['Speed'], ['Age'], ['Speed*Age']]
display_table(models1)
# Out:
# <style  type="text/css" >
#     #T_0026924e_b8e0_11ea_b729_d09466a86f4a th {
#           text-align: center;
#     }    #T_0026924e_b8e0_11ea_b729_d09466a86f4arow0_col3 {
#             color:  red;
#         }    #T_0026924e_b8e0_11ea_b729_d09466a86f4arow0_col6 {
#             color:  black;
#         }    #T_0026924e_b8e0_11ea_b729_d09466a86f4arow0_col9 {
#             color:  black;
#         }    #T_0026924e_b8e0_11ea_b729_d09466a86f4arow1_col3 {
#             color:  black;
#         }    #T_0026924e_b8e0_11ea_b729_d09466a86f4arow1_col6 {
#             color:  black;
#         }    #T_0026924e_b8e0_11ea_b729_d09466a86f4arow1_col9 {
#             color:  black;
#         }    #T_0026924e_b8e0_11ea_b729_d09466a86f4arow2_col3 {
#             color:  red;
#         }    #T_0026924e_b8e0_11ea_b729_d09466a86f4arow2_col6 {
#             color:  black;
#         }    #T_0026924e_b8e0_11ea_b729_d09466a86f4arow2_col9 {
#             color:  black;
# ...

# %% [markdown]
# #### Effect size of regression coefficients

# %%
β_speed = np.empty(len(features)) * np.NaN
β_age   = np.empty(len(features)) * np.NaN
for v, variable in enumerate(features):
    β_speed[v] = models1[4*v][1]
    β_age[v] = models1[4*v+1][4]
β_speed_m, β_speed_std = np.mean(np.abs(β_speed)), np.std(np.abs(β_speed))
β_age_m, β_age_std = np.mean(np.abs(β_age)), np.std(np.abs(β_age))
print('Effect size of speed coefficient: {:.2f}\xB1{:.2f} [{:.2f}, {:.2f}]'
      .format(β_speed_m, β_speed_std, np.min(np.abs(β_speed)), np.max(np.abs(β_speed))))
print('Effect size of age coefficient: {:.2f}\xB1{:.2f} [{:.2f}, {:.2f}]'
      .format(β_age_m, β_age_std, np.min(np.abs(β_age)), np.max(np.abs(β_age))))
# Out:
# Effect size of speed coefficient: 0.64±0.22 [0.26, 0.87]
# Effect size of age coefficient: 0.23±0.12 [0.03, 0.39]

# %% [markdown]
# #### Likelihood-Ratio Test
#
# > "Likelihood-ratio test assesses the goodness of fit of two competing statistical models based on the ratio of their likelihoods."
# See https://en.wikipedia.org/wiki/Likelihood-ratio_test

# %%
llfratio = 2*(fit_ml1[30].llf - fit_ml1[28].llf)
pvalue = stats.chi2.sf(llfratio, 2-1)
print('P value for comparison of models 28 and 30:', pvalue)
llfratio = 2*(fit_ml1[31].llf - fit_ml1[28].llf)
pvalue = stats.chi2.sf(llfratio, 3-1)
print('P value for comparison of models 28 and 31:', pvalue)
# Out:
# P value for comparison of models 28 and 30: 0.009736330863370014
# P value for comparison of models 28 and 31: 0.001593637421159311

# %% [markdown]
# #### Plots with linear regressions per age group
#
# Plot the regression line of the significant model ('feature ~ speed') for all variables but Wnfoot and of the significant model ('feature ~ age + speed') with regression lines for each age group for the variable Wnfoot.

# %%
plot_scatter(data1, fit_re1, predictors, features, labels)

# %% [markdown]
# #### Partial regression plots of the model for the feature 'W-foot'

# %%
fig = plt.figure(figsize=(10, 4))
fig = sm.graphics.plot_partregress_grid(fit_re1[30], grid=(1, 3), fig=fig)

# %%
fig = plt.figure(figsize=(12, 4))
fig = sm.graphics.plot_partregress_grid(fit_re1[31], grid=(1, 4), fig=fig)

# %% [markdown]
# #### Plot of the residuals
#
# Plot the residuals only for the significant model ('feature ~ speed').

# %%
plot_residuals(data1, fit_re1, predictors)

# %% [markdown]
# #### Verification that non-normality of few residuals are due to outliers

# %% [markdown]
# Three (features 'W+foot', 'W-foot', and 'W+sum') out of nine residuals for the significant model 'feature ~ speed' didn't present normal distribution.
# By inspecting the plot of residuals, the cause of the non-normality is likely due to the presence of a few outliers in data. The outliers in this case are values higher than the others at the fast speed condition suggesting a nonlinear behavior for the variable 'Work' at high speeds.
# We will remove these outliers and re-run the models to verify this assertion.

# %%
data1b = data1.drop(index=df1[(np.abs(df1.Wpfoot) > 2) | (np.abs(df1.Wnfoot) > 2)].index,
                    inplace=False)
df1b = data1b.copy(deep=True)
var = ['Speed'] + features
df1b[var] = df1b[var].apply(lambda x: (x-x.mean())/x.std(), axis=0)
df1b.loc[:, 'AgeGroup'].replace({'Y': 0, 'O': 1}, inplace=True)

# %%
display(HTML('<b>Number of subjects per age group and speed condition:</b>'))
display(df1b[['Subject', 'AgeGroup',
              'SpeedGroup']].groupby(['AgeGroup', 'SpeedGroup']).agg('count').T)
# Out:
# <b>Number of subjects per age group and speed condition:</b>
# AgeGroup     0           1
# SpeedGroup   C   F   S   C   F   S
# Subject     24  21  24  16  11  16

# %%
predictors = ['Speed',
              'C(AgeGroup)',
              'Speed + C(AgeGroup)', 
              'Speed * C(AgeGroup)']
groups     = df1b['Subject']

names      = ['Speed', 'C(AgeGroup)[T.1]', 'Speed:C(AgeGroup)[T.1]']
models1b, fit_ml1b, fit_re1b  = runmodels(df1b, predictors, features, groups, names)
# Out:
# Running regression models...
# Model  0: Pankle ~ Speed converged.
# Model  1: Pankle ~ C(AgeGroup) converged.
# Model  2: Pankle ~ Speed + C(AgeGroup) converged.
# Model  3: Pankle ~ Speed * C(AgeGroup) converged.
# Model  4: Pfoot ~ Speed converged.
# Model  5: Pfoot ~ C(AgeGroup) converged.
# Model  6: Pfoot ~ Speed + C(AgeGroup) converged.
# Model  7: Pfoot ~ Speed * C(AgeGroup) converged.
# Model  8: Psum ~ Speed converged.
# Model  9: Psum ~ C(AgeGroup) converged.
# Model 10: Psum ~ Speed + C(AgeGroup) converged.
# Model 11: Psum ~ Speed * C(AgeGroup) converged.
# Model 12: Wpankle ~ Speed converged.
# Model 13: Wpankle ~ C(AgeGroup) converged.
# Model 14: Wpankle ~ Speed + C(AgeGroup) converged.
# Model 15: Wpankle ~ Speed * C(AgeGroup) converged.
# Model 16: Wpfoot ~ Speed converged.
# Model 17: Wpfoot ~ C(AgeGroup) converged.
# Model 18: Wpfoot ~ Speed + C(AgeGroup) converged.
# Model 19: Wpfoot ~ Speed * C(AgeGroup) converged.
# Model 20: Wpsum ~ Speed converged.
# ...

# %%
names = [['Speed'], ['Age'], ['Speed*Age']]
display_table(models1b)
# Out:
# <style  type="text/css" >
#     #T_0701c534_b8e0_11ea_b729_d09466a86f4a th {
#           text-align: center;
#     }    #T_0701c534_b8e0_11ea_b729_d09466a86f4arow0_col3 {
#             color:  red;
#         }    #T_0701c534_b8e0_11ea_b729_d09466a86f4arow0_col6 {
#             color:  black;
#         }    #T_0701c534_b8e0_11ea_b729_d09466a86f4arow0_col9 {
#             color:  black;
#         }    #T_0701c534_b8e0_11ea_b729_d09466a86f4arow1_col3 {
#             color:  black;
#         }    #T_0701c534_b8e0_11ea_b729_d09466a86f4arow1_col6 {
#             color:  black;
#         }    #T_0701c534_b8e0_11ea_b729_d09466a86f4arow1_col9 {
#             color:  black;
#         }    #T_0701c534_b8e0_11ea_b729_d09466a86f4arow2_col3 {
#             color:  red;
#         }    #T_0701c534_b8e0_11ea_b729_d09466a86f4arow2_col6 {
#             color:  black;
#         }    #T_0701c534_b8e0_11ea_b729_d09466a86f4arow2_col9 {
#             color:  black;
# ...

# %%
plot_residuals(data1b, fit_re1b, predictors)

# %% [markdown]
# Indeed, with the removal of a few outliers (some trials at the fast condition), the regression results are overall not changed and all residuals present normal distribution.

# %% [markdown]
# #### The model results are not affected by the order of the predictors

# %%
predictors = ['C(AgeGroup)',
              'Speed',
              'C(AgeGroup) + Speed', 
              'C(AgeGroup) * Speed']
groups     = df1['Subject']

names      = ['C(AgeGroup)[T.1]', 'Speed', 'C(AgeGroup)[T.1]:Speed']
models1c, fit_ml1c, fit_re1c  = runmodels(df1, predictors, features, groups, names)
names = [['Age'], ['Speed'], ['Age*Speed']]
display_table(models1c)
# Out:
# Running regression models...
# Model  0: Pankle ~ C(AgeGroup) converged.
# Model  1: Pankle ~ Speed converged.
# Model  2: Pankle ~ C(AgeGroup) + Speed converged.
# Model  3: Pankle ~ C(AgeGroup) * Speed converged.
# Model  4: Pfoot ~ C(AgeGroup) converged.
# Model  5: Pfoot ~ Speed converged.
# Model  6: Pfoot ~ C(AgeGroup) + Speed converged.
# Model  7: Pfoot ~ C(AgeGroup) * Speed converged.
# Model  8: Psum ~ C(AgeGroup) converged.
# Model  9: Psum ~ Speed converged.
# Model 10: Psum ~ C(AgeGroup) + Speed converged.
# Model 11: Psum ~ C(AgeGroup) * Speed converged.
# Model 12: Wpankle ~ C(AgeGroup) converged.
# Model 13: Wpankle ~ Speed converged.
# Model 14: Wpankle ~ C(AgeGroup) + Speed converged.
# Model 15: Wpankle ~ C(AgeGroup) * Speed converged.
# Model 16: Wpfoot ~ C(AgeGroup) converged.
# Model 17: Wpfoot ~ Speed converged.
# Model 18: Wpfoot ~ C(AgeGroup) + Speed converged.
# Model 19: Wpfoot ~ C(AgeGroup) * Speed converged.
# Model 20: Wpsum ~ C(AgeGroup) converged.
# ...

# %% [markdown]
# ### Age (continuous) and Speed (continuous)
#
# Let's test the robustness of the previous results by running models where 'age' is considered a continuous variable.

# %% [markdown]
# #### Data standardization/normalization

# %%
df2 = data0.copy(deep=True)
var = ['Speed', 'Age'] + features
# Standardization (mean 0, variance 1)
df2[var] = df2[var].apply(lambda x: (x-x.mean())/x.std(), axis=0)

# %% [markdown]
# #### Run models for all predictors and responses

# %%
predictors = ['Speed',
              'Age',
              'Speed + Age', 
              'Speed * Age']
groups     = df2['Subject']

names      = ['Speed', 'Age', 'Speed:Age']
models2, fit_ml2, fit_re2  = runmodels(df2, predictors, features, groups, names)
# Out:
# Running regression models...
# Model  0: Pankle ~ Speed converged.
# Model  1: Pankle ~ Age converged.
# Model  2: Pankle ~ Speed + Age converged.
# Model  3: Pankle ~ Speed * Age converged.
# Model  4: Pfoot ~ Speed converged.
# Model  5: Pfoot ~ Age converged.
# Model  6: Pfoot ~ Speed + Age converged.
# Model  7: Pfoot ~ Speed * Age converged.
# Model  8: Psum ~ Speed converged.
# Model  9: Psum ~ Age converged.
# Model 10: Psum ~ Speed + Age converged.
# Model 11: Psum ~ Speed * Age converged.
# Model 12: Wpankle ~ Speed converged.
# Model 13: Wpankle ~ Age converged.
# Model 14: Wpankle ~ Speed + Age converged.
# Model 15: Wpankle ~ Speed * Age converged.
# Model 16: Wpfoot ~ Speed converged.
# Model 17: Wpfoot ~ Age converged.
# Model 18: Wpfoot ~ Speed + Age converged.
# Model 19: Wpfoot ~ Speed * Age converged.
# Model 20: Wpsum ~ Speed converged.
# Model 21: Wpsum ~ Age converged.
# Model 22: Wpsum ~ Speed + Age converged.
# Model 23: Wpsum ~ Speed * Age converged.
# ...

# %%
fit_re2[30].summary()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#         Mixed Linear Model Regression Results
# ...
# Model:            MixedLM Dependent Variable: Wnfoot
# No. Observations: 123     Method:             REML
# No. Groups:       41      Scale:              0.1785
# Min. group size:  3       Log-Likelihood:     -97.1964
# Max. group size:  3       Converged:          Yes
# Mean group size:  3.0
# ------------------------------------------------------
#            Coef.  Std.Err.    z    P>|z| [0.025 0.975]
# ------------------------------------------------------
# Intercept   0.000    0.069   0.000 1.000 -0.135  0.135
# Speed      -0.818    0.042 -19.689 0.000 -0.900 -0.737
# Age        -0.191    0.069  -2.754 0.006 -0.327 -0.055
# Group Var   0.136    0.127
# ...
#
# """

# %%
fit_re2[31].summary()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#         Mixed Linear Model Regression Results
# ...
# Model:            MixedLM Dependent Variable: Wnfoot
# No. Observations: 123     Method:             REML
# No. Groups:       41      Scale:              0.1639
# Min. group size:  3       Log-Likelihood:     -94.5053
# Max. group size:  3       Converged:          Yes
# Mean group size:  3.0
# ------------------------------------------------------
#            Coef.  Std.Err.    z    P>|z| [0.025 0.975]
# ------------------------------------------------------
# Intercept  -0.009    0.067  -0.129 0.898 -0.141  0.123
# Speed      -0.826    0.040 -20.674 0.000 -0.904 -0.747
# Age        -0.200    0.068  -2.958 0.003 -0.333 -0.068
# Speed:Age  -0.133    0.042  -3.200 0.001 -0.215 -0.052
# Group Var   0.131    0.127
# ...
#
# """

# %% [markdown]
# #### Table with model results

# %%
names = [['Speed'], ['Age'], ['Speed*Age']]
display_table(models2)
# Out:
# <style  type="text/css" >
#     #T_10de888a_b8e0_11ea_b729_d09466a86f4a th {
#           text-align: center;
#     }    #T_10de888a_b8e0_11ea_b729_d09466a86f4arow0_col3 {
#             color:  red;
#         }    #T_10de888a_b8e0_11ea_b729_d09466a86f4arow0_col6 {
#             color:  black;
#         }    #T_10de888a_b8e0_11ea_b729_d09466a86f4arow0_col9 {
#             color:  black;
#         }    #T_10de888a_b8e0_11ea_b729_d09466a86f4arow1_col3 {
#             color:  black;
#         }    #T_10de888a_b8e0_11ea_b729_d09466a86f4arow1_col6 {
#             color:  black;
#         }    #T_10de888a_b8e0_11ea_b729_d09466a86f4arow1_col9 {
#             color:  black;
#         }    #T_10de888a_b8e0_11ea_b729_d09466a86f4arow2_col3 {
#             color:  red;
#         }    #T_10de888a_b8e0_11ea_b729_d09466a86f4arow2_col6 {
#             color:  black;
#         }    #T_10de888a_b8e0_11ea_b729_d09466a86f4arow2_col9 {
#             color:  black;
# ...

# %% [markdown]
# #### Likelihood-Ratio Test

# %%
llfratio = 2*(fit_ml2[20].llf - fit_ml2[22].llf)
pvalue = stats.chi2.sf(llfratio, 2-1)
print('P value for comparison of models 20 and 22:', pvalue)
llfratio = 2*(fit_ml2[20].llf - fit_ml2[23].llf)
pvalue = stats.chi2.sf(llfratio, 2-1)
print('P value for comparison of models 20 and 23:', pvalue)
# Out:
# P value for comparison of models 20 and 22: 1.0
# P value for comparison of models 20 and 23: 0.31367017701453287

# %% [markdown]
# The overall results are similar to the previous regression analysis. Although the observed significant results for the combined model 'feature ~ Speed + Age' for the feature 'W+sum' produced significant additional information in relation to the simpler model 'feature ~ Speed', the corresponding effect sizes are very small.

# %% [markdown]
# ### Age (categorical) and Speed (continuous): slower half of old vs. faster half of young subjects
#
# Let's select sub-groups of the subset to illustrate that the variable 'speed' can be a confounding factor in studies comparing samples of populations where their walking speeds are significantly different, for instance, comparing sedentary older adults with healthy young adults.

# %%
# Median comfortable speed of the Old group
speed = data1.loc[(data1['AgeGroup']=='O') & (data1['SpeedGroup']=='C')]['Speed'].median()
# Select the 50% fastest old subjects and delete their data
idx = data1.loc[(data1['AgeGroup']=='O') & (data1['SpeedGroup']=='C')]['Speed'] > speed
fast_subjects = data1.loc[idx[idx==True].index, 'Subject']
data3 = data1.drop(index=data1.loc[data1['Subject'].isin(fast_subjects)].index, inplace=False)    

# Median comfortable speed of the Young group
speed = data3.loc[(data3['AgeGroup']=='Y') & (data3['SpeedGroup']=='C')]['Speed'].median()
# Select the 50% slowest young subjects and delete their data
idx = data3.loc[(data3['AgeGroup']=='Y') & (data3['SpeedGroup']=='C')]['Speed'] < speed
slow_subjects = data3.loc[idx[idx==True].index, 'Subject']
data3 = data3.drop(index=data3.loc[data3['Subject'].isin(slow_subjects)].index, inplace=False)

# %% [markdown]
# #### Descriptive statistics

# %%
display(HTML('<b>Number of subjects per age group and speed condition:</b>'))
display(data3[['Subject', 'AgeGroup',
               'SpeedGroup']].groupby(['AgeGroup', 'SpeedGroup']).agg('count').T)
display(HTML('<b>Mean and STD values per age group and speed condition:</b>'))
describe(data3[['AgeGroup', 'SpeedGroup', 'Speed'] + features],
         ['AgeGroup', 'SpeedGroup'], var=['mean', 'std']);
# Out:
# <b>Number of subjects per age group and speed condition:</b>
# AgeGroup    O         Y
# SpeedGroup  C  F  S   C   F   S
# Subject     8  8  8  12  12  12
# <b>Mean and STD values per age group and speed condition:</b>
# <style  type="text/css" >
# ...

# %% [markdown]
# #### Simple tests for differences between age groups

# %%
var = ['SpeedGroup', 'AgeGroup', 'Speed'] + features
print('Slow speed')
stats0 = ttest(data3[data3['SpeedGroup']=='S'][var], var[2:], 'AgeGroup', levels=['O', 'Y'])
print('Comfortable speed')
stats0 = ttest(data3[data3['SpeedGroup']=='C'][var], var[2:], 'AgeGroup', levels=['O', 'Y'])
print('Fast speed')
stats0 = ttest(data3[data3['SpeedGroup']=='F'][var], var[2:], 'AgeGroup', levels=['O', 'Y'])
# Out:
# Slow speed
# <style  type="text/css" >
#     #T_10f52374_b8e0_11ea_b729_d09466a86f4arow0_col2 {
#             color:  red;
#         }    #T_10f52374_b8e0_11ea_b729_d09466a86f4arow1_col2 {
#             color:  red;
#         }    #T_10f52374_b8e0_11ea_b729_d09466a86f4arow2_col2 {
#             color:  black;
#         }    #T_10f52374_b8e0_11ea_b729_d09466a86f4arow3_col2 {
#             color:  red;
#         }    #T_10f52374_b8e0_11ea_b729_d09466a86f4arow4_col2 {
#             color:  black;
#         }    #T_10f52374_b8e0_11ea_b729_d09466a86f4arow5_col2 {
#             color:  black;
#         }    #T_10f52374_b8e0_11ea_b729_d09466a86f4arow6_col2 {
#             color:  black;
#         }    #T_10f52374_b8e0_11ea_b729_d09466a86f4arow7_col2 {
#             color:  black;
#         }    #T_10f52374_b8e0_11ea_b729_d09466a86f4arow8_col2 {
#             color:  black;
#         }    #T_10f52374_b8e0_11ea_b729_d09466a86f4arow9_col2 {
#             color:  black;
# ...

# %% [markdown]
# #### Data standardization/normalization

# %%
df3 = data3.copy(deep=True)
var = ['Speed'] + features
# Standardization (mean 0, variance 1)
df3[var] = df3[var].apply(lambda x: (x-x.mean())/x.std(), axis=0)

# %% [markdown]
# #### Replace letters by numeric values because it's easier to identify the effect

# %%
df3.loc[:, 'AgeGroup'].replace({'Y': 0, 'O': 1}, inplace=True)

# %% [markdown]
# #### Run models for all predictors and responses

# %%
predictors = ['C(AgeGroup)',
              'Speed',
              'C(AgeGroup) + Speed', 
              'C(AgeGroup) * Speed']
groups     = df3['Subject']

names      = ['C(AgeGroup)[T.1]', 'Speed', 'C(AgeGroup)[T.1]:Speed']
models3, fit_ml3, fit_re3  = runmodels(df3, predictors, features, groups, names)
# Out:
# Running regression models...
# Model  0: Pankle ~ C(AgeGroup) converged.
# Model  1: Pankle ~ Speed converged.
# Model  2: Pankle ~ C(AgeGroup) + Speed converged.
# Model  3: Pankle ~ C(AgeGroup) * Speed converged.
# Model  4: Pfoot ~ C(AgeGroup) converged.
# Model  5: Pfoot ~ Speed converged.
# Model  6: Pfoot ~ C(AgeGroup) + Speed converged.
# Model  7: Pfoot ~ C(AgeGroup) * Speed converged.
# Model  8: Psum ~ C(AgeGroup) converged.
# Model  9: Psum ~ Speed converged.
# Model 10: Psum ~ C(AgeGroup) + Speed converged.
# Model 11: Psum ~ C(AgeGroup) * Speed converged.
# Model 12: Wpankle ~ C(AgeGroup) converged.
# Model 13: Wpankle ~ Speed converged.
# Model 14: Wpankle ~ C(AgeGroup) + Speed converged.
# Model 15: Wpankle ~ C(AgeGroup) * Speed converged.
# Model 16: Wpfoot ~ C(AgeGroup) converged.
# Model 17: Wpfoot ~ Speed converged.
# Model 18: Wpfoot ~ C(AgeGroup) + Speed converged.
# Model 19: Wpfoot ~ C(AgeGroup) * Speed converged.
# Model 20: Wpsum ~ C(AgeGroup) converged.
# ...

# %%
fit_re3[31].summary()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#               Mixed Linear Model Regression Results
# ...
# Model:                MixedLM     Dependent Variable:     Wnfoot
# No. Observations:     60          Method:                 REML
# No. Groups:           20          Scale:                  0.1871
# Min. group size:      3           Log-Likelihood:         -48.1077
# Max. group size:      3           Converged:              Yes
# Mean group size:      3.0
# ------------------------------------------------------------------
#                        Coef.  Std.Err.    z    P>|z| [0.025 0.975]
# ------------------------------------------------------------------
# Intercept               0.132    0.123   1.077 0.281 -0.108  0.373
# C(AgeGroup)[T.1]       -0.440    0.203  -2.171 0.030 -0.838 -0.043
# Speed                  -0.841    0.074 -11.435 0.000 -0.985 -0.697
# C(AgeGroup)[T.1]:Speed -0.218    0.150  -1.452 0.147 -0.513  0.076
# Group Var               0.112    0.163
# ...
#
# """

# %% [markdown]
# #### Table with model results

# %%
names = [['Age'], ['Speed'], ['Age*Speed']]
display_table(models3)
# Out:
# <style  type="text/css" >
#     #T_15037e84_b8e0_11ea_b729_d09466a86f4a th {
#           text-align: center;
#     }    #T_15037e84_b8e0_11ea_b729_d09466a86f4arow0_col3 {
#             color:  red;
#         }    #T_15037e84_b8e0_11ea_b729_d09466a86f4arow0_col6 {
#             color:  black;
#         }    #T_15037e84_b8e0_11ea_b729_d09466a86f4arow0_col9 {
#             color:  black;
#         }    #T_15037e84_b8e0_11ea_b729_d09466a86f4arow1_col3 {
#             color:  black;
#         }    #T_15037e84_b8e0_11ea_b729_d09466a86f4arow1_col6 {
#             color:  red;
#         }    #T_15037e84_b8e0_11ea_b729_d09466a86f4arow1_col9 {
#             color:  black;
#         }    #T_15037e84_b8e0_11ea_b729_d09466a86f4arow2_col3 {
#             color:  black;
#         }    #T_15037e84_b8e0_11ea_b729_d09466a86f4arow2_col6 {
#             color:  red;
#         }    #T_15037e84_b8e0_11ea_b729_d09466a86f4arow2_col9 {
#             color:  black;
# ...

# %% [markdown]
# Six out of the nine features showed significant effect of the variable 'Age' for the regression model 'feature ~ Age'.
# However, when the effect of the variable 'Speed' was considered in the regression model 'feature ~ Speed + Age', the effect of 'Age' was vanished for all features, except for the negative work of the foot, consistent with our previous results.
# In addition, the model 'feature ~ Speed' always explained more of the variation in the response (higher R2 values) than the model 'feature ~ Age'.
